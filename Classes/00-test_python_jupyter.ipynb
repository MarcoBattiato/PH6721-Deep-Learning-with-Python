# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MarcoBattiato/PH6721-Deep-Learning-with-Python/blob/main/Classes/00-test_python_jupyter.ipynb)
#
# # Welcome to PH6721
#
# **Instructor:** Marco Battiato (Prev. Nanyang Assistant Professor, Curr. Quantitative Researcher @ hedge fund)
#
# **email:** marco.battiato.teaching@gmail.com
#
# **In Person Classes:**  Wednesday 6:30pm - 9:45pm ()
#
# 02 Dec 26 (TUE): 7:00pm-10:15pm (lesson starts half hr later than usual)
#
# 09 Dec 26 (TUE): 7:00pm-10:15pm (lesson starts half hr later than usual)
#
# **Consultation:** Tuesday 12:30 - 13:30 (Tentative)
#
#
# Classes will be a mix of theory and practice. You will be often asked to write, modify or test small programs.
#
# You are expected to bring and use your laptop.
#
#
# # Jupyter and Python - Test
# (by Marco Battiato. For questions/errors/bugs/typos report, please email at marco.battiato.teaching@gmail.com)
#
# If you are reading this, you have already installed both Python and Jupyter.
#
# ## Markdown Cells
#
# You can modify this text by clicking on the cell (this cell is called markdown cell) and pressing `Enter`.
# You can then modify the text of the markdown cell as in a normal text editor.
# You can exit the edit mode by pressing `Ctrl-Enter` on Windows and `Command-Enter` on Mac.
#
# Try it now. Do not delete this text ;)
#
# ## Code Cells
#
# The next cell is instead a code cell. You can write code in a code cell, as if you were in a common text editor.
# You execute the whole cell by pressing `Ctrl-Enter` on Windows and `Command-Enter` on Mac.
#
# Try it now

# %%
from numpy import *
import matplotlib.pyplot as plt

## Plot tan(x) over an appropriate x range.
x = linspace(-6., 6., 200)
y = tan(x)
plt.plot(x, y)

## Format the figure nicely.
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = tan(x)')
plt.ylim(-10., 10.);

# %% [markdown]
# Has a plot appeared?
