# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MarcoBattiato/PH6721-Deep-Learning-with-Python/blob/main/Classes/Class_0/00A-StartHere.ipynb)
#
# # 00A — Start Here
# (by Marco Battiato. For questions/errors/bugs/typos report, please email at marco.battiato.teaching@gmail.com)
#
# **PH6721 — Deep Learning with Python**
# **Before Class 1**
#
# **Instructor:** Marco Battiato (formerly Nanyang Assistant Professor @ Nanyang Technological University)
#
# **email:**  marco.battiato.teaching@gmail.com
#
# **In Person Classes:**  Wednesday 6:30pm - 9:45pm
#
# **Consultation:** remote consultations are to be arranged by writing to marco.battiato.teaching@gmail.com
#
# This is the first notebook of the course, and it takes about ten minutes.
#
# It does two things:
#
# 1. **checks that Colab works for you**, so that nothing has to be fixed during the first class;
# 2. **helps you decide whether to work through the Python primer** (`00B-IntroToPython`) before
#    Class 1.
#
# The course assumes you can already read and write basic Python. It does **not** assume you have
# used NumPy, pandas, or any machine-learning library. Those are taught from scratch in Class 1.

# %% [markdown]
# # Part 1 — Does everything work?
#
# Run the cell below. It imports the three libraries used throughout the course and draws a simple
# plot.
#
# To run a cell, click it and press `Shift` + `Enter`.
#
# **Run this cell yourself. Its output is not stored in the notebook.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.linspace(-6, 6, 200)
y = np.sin(x)

plt.figure(figsize=(6, 3))
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("If you can see this curve, your setup works — continue to Part 2")
plt.grid(alpha=0.3)
plt.show()

print("NumPy      ", np.__version__)
print("pandas     ", pd.__version__)
print("matplotlib ", plt.matplotlib.__version__)

# %% [markdown]
# **Did a sine curve appear, followed by three version numbers?**
#
# - **Yes** — your setup is fine. Continue to Part 2.
# - **No** — check that you opened this notebook through the *Open in Colab* badge and that you are
#   signed in to a Google account. The step-by-step instructions are in
#   [`GettingStarted.md`](https://github.com/MarcoBattiato/PH6721-Deep-Learning-with-Python/blob/main/GettingStarted.md).
#   If it still fails, email me before the first class rather than during it.
#
# You do not need to understand the code above. You will by the end of Class 1.

# %% [markdown]
# # Part 2 — Do you need the Python primer?
#
# Eight short questions. They cover exactly the Python that Class 1 assumes you already have.
#
# **For each one: work out the answer in your head first, then run the cell to check.** Keep count
# of how many you get wrong — the scoring rule is at the end.
#
# Do not worry if you have never seen NumPy or pandas. None of these questions involve them.

# %% [markdown]
# ### Question 1 — Indexing a list
#
# `values = [10, 20, 30, 40, 50]`
#
# What do `values[0]` and `values[-1]` print?
#
# **Think about your answer before running this cell.**

# %%
values = [10, 20, 30, 40, 50]

print(values[0])
print(values[-1])

# %% [markdown]
# ### Question 2 — Slicing a list
#
# Using the same list, what does `values[1:4]` print? How many elements does it contain?
#
# **Think about your answer before running this cell.**

# %%
print(values[1:4])
print(len(values[1:4]))

# %% [markdown]
# ### Question 3 — A loop and a total
#
# What does this print? Work out the arithmetic before running it.
#
# **Think about your answer before running this cell.**

# %%
total = 0

for i in range(5):
    total += i

print(total)

# %% [markdown]
# ### Question 4 — Writing a function
#
# What does this print?
#
# **Think about your answer before running this cell.**

# %%
def area(width, height):
    return width * height

print(area(3, 4))
print(area(height=10, width=2))

# %% [markdown]
# ### Question 5 — A dictionary
#
# What do the two lines print? What would happen if you asked for a key that is not there?
#
# **Think about your answer before running this cell.**

# %%
masses = {"hydrogen": 1.008, "helium": 4.003, "lithium": 6.941}

print(masses["helium"])
print(len(masses))

# %% [markdown]
# ### Question 6 — Formatting a string
#
# What exactly does this print, including the number of decimal places?
#
# **Think about your answer before running this cell.**

# %%
name = "helium"
mass = 4.002602

print(f"The mass of {name} is {mass:.2f}")

# %% [markdown]
# ### Question 7 — A condition
#
# What does this print? Notice that the list is looped over, not just tested once.
#
# **Think about your answer before running this cell.**

# %%
for value in [3, 8, 12]:
    if value > 10:
        print(value, "is large")
    elif value > 5:
        print(value, "is medium")
    else:
        print(value, "is small")

# %% [markdown]
# ### Question 8 — A list comprehension
#
# What list does this produce? If the syntax is unfamiliar, that is worth knowing — it appears
# throughout the course.
#
# **Think about your answer before running this cell.**

# %%
squares = [v**2 for v in range(6) if v % 2 == 0]

print(squares)

# %% [markdown]
# # Part 3 — What to do next
#
# Count how many of the eight you predicted **incorrectly**.
#
# | Wrong | What to do |
# |---|---|
# | **0–2** | You are ready. Go straight to Class 1. Skim `00B-IntroToPython` only if a specific question caught you out — the table below says which section covers what. |
# | **3–5** | Work through `00B-IntroToPython` before Class 1. You can move quickly through the parts you already know. |
# | **6–8** | Work through `00B-IntroToPython` carefully, doing the exercises. Budget two or three hours. It is worth it: Class 1 Hour 2 moves fast, and it assumes all of this. |
#
# ### Which section covers which question
#
# | Question | Topic | Section of `00B-IntroToPython` |
# |---|---|---|
# | 1 | Indexing a list | §6.1 |
# | 2 | Slicing a list | §6.1 |
# | 3 | Loops and `range` | §9.3 |
# | 4 | Functions and arguments | §10 |
# | 5 | Dictionaries | §7.2 |
# | 6 | f-strings | §3.2, §3.3 |
# | 7 | Conditionals | §9.2 |
# | 8 | List comprehensions | §9.4 |
#
# Being honest with yourself here costs ten minutes now and saves a difficult evening in week one.

# %% [markdown]
# # What Class 1 does *not* assume
#
# To be clear about the boundary, you are **not** expected to know any of the following before the
# course. All of it is taught from the beginning:
#
# - NumPy arrays, shapes, broadcasting — Class 1, notebook `01B`
# - pandas, DataFrames, exploratory data analysis — Class 1, notebook `01C`
# - anything about machine learning at all — from Class 1 onward
# - PyTorch, neural networks — from Class 7 onward
#
# If you have never heard of any of these, you are in the right place.

# %% [markdown]
# # Before the first class
#
# - [ ] The sine curve in Part 1 appeared
# - [ ] You have worked through the eight questions and know your score
# - [ ] If you scored 3 or more wrong, you have started `00B-IntroToPython`
# - [ ] You have bookmarked the
#       [course page](https://github.com/MarcoBattiato/PH6721-Deep-Learning-with-Python)
# - [ ] You are bringing a laptop to class
#
# See you in Class 1.
